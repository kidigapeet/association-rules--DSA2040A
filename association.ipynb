# %%
# %pip install mlxtend
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting mlxtend
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 524.3 kB/s eta 0:00:02
#    ----------------------- ---------------- 0.8/1.4 MB 780.2 kB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.4 MB 949.8 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 996.5 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# A simple example to demostrate association rules in python using mlxtend library
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

#sample dataset
#each row represent a shopping basket with items purchased
dataset = [['Milk', 'Bread', 'Eggs'],
           ['Bread', 'Diapers', 'Beer', 'Eggs'],
           ['Milk', 'Diapers', 'Bread', 'Cola'],
           ['Bread', 'Milk', 'Diapers', 'Beer'],
           ['Milk', 'Bread', 'Diapers', 'Eggs']]

#convert dataset into one-hot encoded dataframe
#each item becomes a column with True/False for presence in the basket  its own column with truue/false values indicating getspresence/absence in the basket
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
print(df)

# find frequent itemsets
freq_items = apriori(df, min_support=0.6, use_colnames=True)
print("Frequent itemsets:")
print(freq_items)

# generate association rules
rules = association_rules(freq_items, metric="confidence", min_threshold=0.7)
print("Association rules:")
print(rules)
# Out:
#     Beer  Bread   Cola  Diapers   Eggs   Milk
# 0  False   True  False    False   True   True
# 1   True   True  False     True   True  False
# 2  False   True   True     True  False   True
# 3   True   True  False     True  False   True
# 4  False   True  False     True   True   True
# Frequent itemsets:
#    support                itemsets
# 0      1.0                 (Bread)
# 1      0.8               (Diapers)
# 2      0.6                  (Eggs)
# 3      0.8                  (Milk)
# 4      0.8        (Diapers, Bread)
# 5      0.6           (Bread, Eggs)
# 6      0.8           (Bread, Milk)
# 7      0.6         (Diapers, Milk)
# 8      0.6  (Diapers, Bread, Milk)
# Association rules:
#          antecedents       consequents  antecedent support  \
# 0          (Diapers)           (Bread)                 0.8
# 1            (Bread)         (Diapers)                 1.0
# 2             (Eggs)           (Bread)                 0.6
# ...
